# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models  #type:ignore
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import mean_squared_error
from tensorflow.keras import regularizers
# Out:
# 2026-04-30 11:16:55.054862: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777547815.249436      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777547815.300927      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777547815.727207      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777547815.727252      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777547815.727255      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777547815.727257      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
cols = ['unit', 'cycle', 'os1', 'os2', 'os3'] + [f's{i}' for i in range(1, 22)]

def load_data(path):
    return pd.read_csv(path, sep=' +', header=None,
                       usecols=range(26), names=cols, engine='python')

train = load_data('/kaggle/input/datasets/bishals098/nasa-turbofan-engine-degradation-simulation/train_FD004.txt')
test  = load_data('/kaggle/input/datasets/bishals098/nasa-turbofan-engine-degradation-simulation/test_FD004.txt')
rul   = pd.read_csv('/kaggle/input/datasets/bishals098/nasa-turbofan-engine-degradation-simulation/RUL_FD004.txt', header=None, names=['rul'])

# %%
train.head()
# Out:
#    unit  cycle      os1     os2    os3      s1      s2       s3       s4  \
# 0     1      1  42.0049  0.8400  100.0  445.00  549.68  1343.43  1112.93
# 1     1      2  20.0020  0.7002  100.0  491.19  606.07  1477.61  1237.50
# 2     1      3  42.0038  0.8409  100.0  445.00  548.95  1343.12  1117.05
# 3     1      4  42.0000  0.8400  100.0  445.00  548.70  1341.24  1118.03
# 4     1      5  25.0063  0.6207   60.0  462.54  536.10  1255.23  1033.59
#
#      s5  ...     s12      s13      s14      s15   s16  s17   s18     s19  \
# 0  3.91  ...  129.78  2387.99  8074.83   9.3335  0.02  330  2212  100.00
# 1  9.35  ...  312.59  2387.73  8046.13   9.1913  0.02  361  2324  100.00
# 2  3.91  ...  129.62  2387.97  8066.62   9.4007  0.02  329  2212  100.00
# 3  3.91  ...  129.80  2388.02  8076.05   9.3369  0.02  328  2212  100.00
# 4  7.05  ...  164.11  2028.08  7865.80  10.8366  0.02  305  1915   84.93
#
#      s20      s21
# 0  10.62   6.3670
# 1  24.37  14.6552
# 2  10.48   6.4213
# 3  10.54   6.4176
# 4  14.03   8.6754
#
# [5 rows x 26 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   unit    61249 non-null  int64
#  1   cycle   61249 non-null  int64
#  2   os1     61249 non-null  float64
#  3   os2     61249 non-null  float64
#  4   os3     61249 non-null  float64
#  5   s1      61249 non-null  float64
#  6   s2      61249 non-null  float64
#  7   s3      61249 non-null  float64
#  8   s4      61249 non-null  float64
#  9   s5      61249 non-null  float64
#  10  s6      61249 non-null  float64
#  11  s7      61249 non-null  float64
#  12  s8      61249 non-null  float64
#  13  s9      61249 non-null  float64
#  14  s10     61249 non-null  float64
#  15  s11     61249 non-null  float64
#  16  s12     61249 non-null  float64
#  17  s13     61249 non-null  float64
#  18  s14     61249 non-null  float64
#  19  s15     61249 non-null  float64
#  20  s16     61249 non-null  float64
#  21  s17     61249 non-null  int64
#  22  s18     61249 non-null  int64
#  23  s19     61249 non-null  float64
#  24  s20     61249 non-null  float64
#  25  s21     61249 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 12.1 MB

# %%
DROP_SENSORS = ['s1','s5','s6','s8','s10','s13','s15','s16','s18','s19']
KEEP_SENSORS = ['s2','s3','s4','s7','s9','s11','s12','s14','s17','s20','s21']

train.drop(columns=DROP_SENSORS, inplace=True)
test.drop(columns=DROP_SENSORS, inplace=True)

# %%
def add_rul(df):
    max_cycle = df.groupby('unit')['cycle'].transform('max')
    df['RUL'] = max_cycle - df['cycle']
    return df

train = add_rul(train)

last_cycles = test.groupby('unit')['cycle'].max().reset_index()
last_cycles['RUL'] = rul['rul'].values
test = test.merge(last_cycles[['unit','RUL']], on='unit', how='left')
test_last = test.groupby('unit').last().reset_index()

# %%
RUL_CLIP = 125
train['RUL'] = train['RUL'].clip(upper=RUL_CLIP)

# %%
SETTING_COLS = ['os1', 'os2', 'os3']
kmeans = KMeans(n_clusters=6, random_state=42, n_init=10)
train['condition'] = kmeans.fit_predict(train[SETTING_COLS])
test['condition']  = kmeans.predict(test[SETTING_COLS])

# %%
train[KEEP_SENSORS] = train[KEEP_SENSORS].astype(np.float64)
test[KEEP_SENSORS]  = test[KEEP_SENSORS].astype(np.float64)

scalers = {}
for cond in range(6):
    scaler = MinMaxScaler()
    mask_tr = train['condition'] == cond
    mask_te = test['condition']  == cond
    train.loc[mask_tr, KEEP_SENSORS] = scaler.fit_transform(train.loc[mask_tr, KEEP_SENSORS])
    if mask_te.sum() > 0:
        test.loc[mask_te, KEEP_SENSORS] = scaler.transform(test.loc[mask_te, KEEP_SENSORS])
    scalers[cond] = scaler

# %%
print("=== RUL range (train should max at 125) ===")
print(f"Train RUL: min={train['RUL'].min()}, max={train['RUL'].max()}")
print(f"Test  RUL: min={test_last['RUL'].min()}, max={test_last['RUL'].max()}")

print("\n=== Sensor range (should be 0.0 to 1.0) ===")

train_min = train[KEEP_SENSORS].min().min()
train_max = train[KEEP_SENSORS].max().max()

test_min = test[KEEP_SENSORS].min().min()
test_max = test[KEEP_SENSORS].max().max()

print("Train:", round(train_min, 3), "to", round(train_max, 3))
print("Test: ", round(test_min, 3),  "to", round(test_max, 3))
# Out:
# === RUL range (train should max at 125) ===
# Train RUL: min=0, max=125
# Test  RUL: min=6, max=195
#
# === Sensor range (should be 0.0 to 1.0) ===
# Train: 0.0 to 1.0
# Test:  -0.091 to 1.009

# %%
WINDOW   = 50
RUL_CLIP = 125

def build_sequences(df, feature_cols, window=WINDOW):
    X, y = [], []
    for _, engine_df in df.groupby('unit'):
        engine_df = engine_df.sort_values('cycle')
        data, labels = engine_df[feature_cols].values, engine_df['RUL'].values
        for i in range(len(data) - window + 1):
            X.append(data[i:i+window])
            y.append(labels[i+window-1])
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def build_last_sequences(df, feature_cols, window=WINDOW):
    X, y = [], []
    for _, engine_df in df.groupby('unit'):
        engine_df = engine_df.sort_values('cycle')
        data = engine_df[feature_cols].values
        if len(data) >= window:
            X.append(data[-window:])
        else:
            pad = np.zeros((window - len(data), len(feature_cols)))
            X.append(np.vstack([pad, data]))
        y.append(engine_df['RUL'].iloc[-1])
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

# %%
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, val_idx = next(gss.split(train, groups=train['unit']))

X_train, y_train_raw = build_sequences(train.iloc[train_idx], KEEP_SENSORS, WINDOW)
X_val,   y_val_raw   = build_sequences(train.iloc[val_idx],   KEEP_SENSORS, WINDOW)
X_test,  y_test_raw  = build_last_sequences(test, KEEP_SENSORS, WINDOW)

y_train = (y_train_raw / RUL_CLIP).astype(np.float32)
y_val   = (y_val_raw   / RUL_CLIP).astype(np.float32)
y_test_clipped = np.clip(y_test_raw, 0, RUL_CLIP).astype(np.float32)

print("=== Data shapes ===")
print(f"Sequences rebuilt with window={WINDOW}")
print(f"X_train={X_train.shape}, X_val={X_val.shape}, X_test={X_test.shape}")
print(f"y_train: min={y_train.min():.3f}, max={y_train.max():.3f}  (should be 0.0–1.0)")
print(f"y_val:   min={y_val.min():.3f},   max={y_val.max():.3f}")
print(f"y_test_clipped (cycles): min={y_test_clipped.min()}, max={y_test_clipped.max()}")
# Out:
# === Data shapes ===
# Sequences rebuilt with window=50
# X_train=(39543, 50, 11), X_val=(9505, 50, 11), X_test=(248, 50, 11)
# y_train: min=0.000, max=1.000  (should be 0.0–1.0)
# y_val:   min=0.000,   max=1.000
# y_test_clipped (cycles): min=6.0, max=125.0

# %%
unique, counts = np.unique((y_train_raw // 10) * 10, return_counts=True)
print("RUL distribution BEFORE rebalance:")
for u, c in zip(unique, counts):
    bar = '💀' * (c // 200)
    print(f"  RUL {int(u):3d}-{int(u+9):3d}: {c:5d}  {bar}")
# Out:
# RUL distribution BEFORE rebalance:
#   RUL   0-  9:  1990  💀💀💀💀💀💀💀💀💀
#   RUL  10- 19:  1990  💀💀💀💀💀💀💀💀💀
#   RUL  20- 29:  1990  💀💀💀💀💀💀💀💀💀
#   RUL  30- 39:  1990  💀💀💀💀💀💀💀💀💀
#   RUL  40- 49:  1990  💀💀💀💀💀💀💀💀💀
#   RUL  50- 59:  1990  💀💀💀💀💀💀💀💀💀
#   RUL  60- 69:  1990  💀💀💀💀💀💀💀💀💀
#   RUL  70- 79:  1989  💀💀💀💀💀💀💀💀💀
#   RUL  80- 89:  1980  💀💀💀💀💀💀💀💀💀
#   RUL  90- 99:  1960  💀💀💀💀💀💀💀💀💀
#   RUL 100-109:  1910  💀💀💀💀💀💀💀💀💀
#   RUL 110-119:  1830  💀💀💀💀💀💀💀💀💀
#   RUL 120-129: 15944  💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀💀

# %%
def rebalance_sequences(X, y_raw, bucket_size=10, max_per_bucket=800):
    buckets  = (y_raw // bucket_size).astype(int)
    keep_idx = []
    for b in np.unique(buckets):
        idx = np.where(buckets == b)[0]
        if len(idx) > max_per_bucket:
            idx = np.random.choice(idx, max_per_bucket, replace=False)
        keep_idx.append(idx)
    keep_idx = np.concatenate(keep_idx)
    np.random.shuffle(keep_idx)
    return X[keep_idx], y_raw[keep_idx]

# %%
np.random.seed(42)
X_train, y_train_raw = rebalance_sequences(X_train, y_train_raw, max_per_bucket=800)

unique, counts = np.unique((y_train_raw // 10) * 10, return_counts=True)
print(f"\nRUL distribution AFTER rebalance (total={len(X_train)}):")
for u, c in zip(unique, counts):
    bar = '😎' * (c // 200)
    print(f"  RUL {int(u):3d}-{int(u+9):3d}: {c:5d}  {bar}")

# NOW normalize
y_train = (y_train_raw / RUL_CLIP).astype(np.float32)
sample_weights = (1.0 + 1.5 * (y_train_raw / RUL_CLIP)).astype(np.float32)
# Out:
# RUL distribution AFTER rebalance (total=10400):
#   RUL   0-  9:   800  😎😎😎😎
#   RUL  10- 19:   800  😎😎😎😎
#   RUL  20- 29:   800  😎😎😎😎
#   RUL  30- 39:   800  😎😎😎😎
#   RUL  40- 49:   800  😎😎😎😎
#   RUL  50- 59:   800  😎😎😎😎
#   RUL  60- 69:   800  😎😎😎😎
#   RUL  70- 79:   800  😎😎😎😎
#   RUL  80- 89:   800  😎😎😎😎
#   RUL  90- 99:   800  😎😎😎😎
#   RUL 100-109:   800  😎😎😎😎
#   RUL 110-119:   800  😎😎😎😎
#   RUL 120-129:   800  😎😎😎😎

# %%
def build_gru(window, n_features):
    inp = tf.keras.Input(shape=(window, n_features))
    x = layers.GRU(128, return_sequences=True)(inp)
    x = layers.Dropout(0.2)(x)
    x = layers.GRU(64, return_sequences=True)(x)
    x = layers.Dropout(0.2)(x)
    x = layers.GRU(32)(x)
    x = layers.Dropout(0.15)(x)
    x = layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.Dense(16, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    out = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inp, out)

# %%
model = build_gru(WINDOW, len(KEEP_SENSORS))
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss='mse', 
    metrics=[tf.keras.metrics.RootMeanSquaredError(name='rmse')]
)
model.summary()
# Out:
# I0000 00:00:1777547845.639837      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 50, 11)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 50, 128)        │        54,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 50, 64)         │        37,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 102,401 (400.00 KB)
#  Trainable params: 102,401 (400.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=10,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5,
        patience=5, min_lr=1e-5, verbose=1
    )
]

sample_weights = (1.0 + 1.5 * (y_train_raw / RUL_CLIP)).astype(np.float32)

history = model.fit(
    X_train, y_train,       
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=512,
    sample_weight=sample_weights,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# I0000 00:00:1777547850.829384     132 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 0.1625 - rmse: 0.3000 - val_loss: 0.1176 - val_rmse: 0.3353 - learning_rate: 3.0000e-04
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1347 - rmse: 0.2825 - val_loss: 0.0828 - val_rmse: 0.2788 - learning_rate: 3.0000e-04
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0883 - rmse: 0.2255 - val_loss: 0.0484 - val_rmse: 0.2083 - learning_rate: 3.0000e-04
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0634 - rmse: 0.1822 - val_loss: 0.0459 - val_rmse: 0.2024 - learning_rate: 3.0000e-04
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0580 - rmse: 0.1723 - val_loss: 0.0486 - val_rmse: 0.2089 - learning_rate: 3.0000e-04
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0549 - rmse: 0.1650 - val_loss: 0.0433 - val_rmse: 0.1961 - learning_rate: 3.0000e-04
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0544 - rmse: 0.1641 - val_loss: 0.0427 - val_rmse: 0.1948 - learning_rate: 3.0000e-04
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0541 - rmse: 0.1647 - val_loss: 0.0451 - val_rmse: 0.2010 - learning_rate: 3.0000e-04
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0524 - rmse: 0.1605 - val_loss: 0.0430 - val_rmse: 0.1957 - learning_rate: 3.0000e-04
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0507 - rmse: 0.1581 - val_loss: 0.0464 - val_rmse: 0.2044 - learning_rate: 3.0000e-04
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0509 - rmse: 0.1578 - val_loss: 0.0423 - val_rmse: 0.1943 - learning_rate: 3.0000e-04
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0510 - rmse: 0.1584 - val_loss: 0.0428 - val_rmse: 0.1956 - learning_rate: 3.0000e-04
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0502 - rmse: 0.1570 - val_loss: 0.0416 - val_rmse: 0.1928 - learning_rate: 3.0000e-04
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0493 - rmse: 0.1559 - val_loss: 0.0414 - val_rmse: 0.1923 - learning_rate: 3.0000e-04
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0492 - rmse: 0.1553 - val_loss: 0.0416 - val_rmse: 0.1930 - learning_rate: 3.0000e-04
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0474 - rmse: 0.1521 - val_loss: 0.0400 - val_rmse: 0.1890 - learning_rate: 3.0000e-04
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0476 - rmse: 0.1528 - val_loss: 0.0400 - val_rmse: 0.1893 - learning_rate: 3.0000e-04
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0462 - rmse: 0.1503 - val_loss: 0.0415 - val_rmse: 0.1931 - learning_rate: 3.0000e-04
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0458 - rmse: 0.1488 - val_loss: 0.0443 - val_rmse: 0.2003 - learning_rate: 3.0000e-04
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0475 - rmse: 0.1513 - val_loss: 0.0395 - val_rmse: 0.1882 - learning_rate: 3.0000e-04
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0446 - rmse: 0.1468 - val_loss: 0.0373 - val_rmse: 0.1823 - learning_rate: 3.0000e-04
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0420 - rmse: 0.1424 - val_loss: 0.0353 - val_rmse: 0.1769 - learning_rate: 3.0000e-04
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0400 - rmse: 0.1373 - val_loss: 0.0307 - val_rmse: 0.1636 - learning_rate: 3.0000e-04
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0349 - rmse: 0.1274 - val_loss: 0.0300 - val_rmse: 0.1616 - learning_rate: 3.0000e-04
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0327 - rmse: 0.1220 - val_loss: 0.0265 - val_rmse: 0.1508 - learning_rate: 3.0000e-04
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0315 - rmse: 0.1197 - val_loss: 0.0255 - val_rmse: 0.1476 - learning_rate: 3.0000e-04
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0311 - rmse: 0.1191 - val_loss: 0.0304 - val_rmse: 0.1634 - learning_rate: 3.0000e-04
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0302 - rmse: 0.1169 - val_loss: 0.0248 - val_rmse: 0.1452 - learning_rate: 3.0000e-04
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0292 - rmse: 0.1145 - val_loss: 0.0248 - val_rmse: 0.1456 - learning_rate: 3.0000e-04
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0287 - rmse: 0.1139 - val_loss: 0.0251 - val_rmse: 0.1467 - learning_rate: 3.0000e-04
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0292 - rmse: 0.1145 - val_loss: 0.0265 - val_rmse: 0.1514 - learning_rate: 3.0000e-04
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0283 - rmse: 0.1127 - val_loss: 0.0239 - val_rmse: 0.1426 - learning_rate: 3.0000e-04
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0283 - rmse: 0.1126 - val_loss: 0.0244 - val_rmse: 0.1445 - learning_rate: 3.0000e-04
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0280 - rmse: 0.1125 - val_loss: 0.0256 - val_rmse: 0.1489 - learning_rate: 3.0000e-04
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0277 - rmse: 0.1113 - val_loss: 0.0248 - val_rmse: 0.1462 - learning_rate: 3.0000e-04
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0281 - rmse: 0.1123 - val_loss: 0.0234 - val_rmse: 0.1415 - learning_rate: 3.0000e-04
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0283 - rmse: 0.1135 - val_loss: 0.0263 - val_rmse: 0.1517 - learning_rate: 3.0000e-04
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0271 - rmse: 0.1099 - val_loss: 0.0246 - val_rmse: 0.1457 - learning_rate: 3.0000e-04
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0266 - rmse: 0.1091 - val_loss: 0.0234 - val_rmse: 0.1420 - learning_rate: 3.0000e-04
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0272 - rmse: 0.1111 - val_loss: 0.0236 - val_rmse: 0.1428 - learning_rate: 3.0000e-04
# Epoch 41/100
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0268 - rmse: 0.1096
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0268 - rmse: 0.1095 - val_loss: 0.0243 - val_rmse: 0.1453 - learning_rate: 3.0000e-04
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0270 - rmse: 0.1101 - val_loss: 0.0232 - val_rmse: 0.1414 - learning_rate: 1.5000e-04
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0259 - rmse: 0.1078 - val_loss: 0.0256 - val_rmse: 0.1497 - learning_rate: 1.5000e-04
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0264 - rmse: 0.1085 - val_loss: 0.0231 - val_rmse: 0.1411 - learning_rate: 1.5000e-04
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0264 - rmse: 0.1098 - val_loss: 0.0243 - val_rmse: 0.1455 - learning_rate: 1.5000e-04
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0260 - rmse: 0.1077 - val_loss: 0.0237 - val_rmse: 0.1435 - learning_rate: 1.5000e-04
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0256 - rmse: 0.1073 - val_loss: 0.0234 - val_rmse: 0.1423 - learning_rate: 1.5000e-04
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0263 - rmse: 0.1087 - val_loss: 0.0242 - val_rmse: 0.1453 - learning_rate: 1.5000e-04
# Epoch 49/100
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0265 - rmse: 0.1094
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0264 - rmse: 0.1094 - val_loss: 0.0241 - val_rmse: 0.1449 - learning_rate: 1.5000e-04
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0256 - rmse: 0.1072 - val_loss: 0.0233 - val_rmse: 0.1422 - learning_rate: 7.5000e-05
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0261 - rmse: 0.1086 - val_loss: 0.0229 - val_rmse: 0.1409 - learning_rate: 7.5000e-05
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0257 - rmse: 0.1080 - val_loss: 0.0238 - val_rmse: 0.1442 - learning_rate: 7.5000e-05
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0256 - rmse: 0.1074 - val_loss: 0.0247 - val_rmse: 0.1472 - learning_rate: 7.5000e-05
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0262 - rmse: 0.1079 - val_loss: 0.0226 - val_rmse: 0.1397 - learning_rate: 7.5000e-05
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0257 - rmse: 0.1081 - val_loss: 0.0234 - val_rmse: 0.1426 - learning_rate: 7.5000e-05
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0258 - rmse: 0.1077 - val_loss: 0.0230 - val_rmse: 0.1413 - learning_rate: 7.5000e-05
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0253 - rmse: 0.1067 - val_loss: 0.0237 - val_rmse: 0.1437 - learning_rate: 7.5000e-05
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0252 - rmse: 0.1065 - val_loss: 0.0235 - val_rmse: 0.1432 - learning_rate: 7.5000e-05
# Epoch 59/100
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0267 - rmse: 0.1099
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0266 - rmse: 0.1095 - val_loss: 0.0242 - val_rmse: 0.1456 - learning_rate: 7.5000e-05
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0255 - rmse: 0.1067 - val_loss: 0.0233 - val_rmse: 0.1425 - learning_rate: 3.7500e-05
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0253 - rmse: 0.1069 - val_loss: 0.0233 - val_rmse: 0.1427 - learning_rate: 3.7500e-05
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0254 - rmse: 0.1069 - val_loss: 0.0234 - val_rmse: 0.1427 - learning_rate: 3.7500e-05
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0246 - rmse: 0.1053 - val_loss: 0.0232 - val_rmse: 0.1423 - learning_rate: 3.7500e-05
# Epoch 64/100
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0268 - rmse: 0.1099
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0266 - rmse: 0.1096 - val_loss: 0.0233 - val_rmse: 0.1427 - learning_rate: 3.7500e-05
# Epoch 64: early stopping
# Restoring model weights from the end of the best epoch: 54.

# %%
def nasa_score(y_true, y_pred):
    d = y_pred.flatten() - y_true.flatten()
    return float(np.sum(np.where(d < 0, np.exp(-d/13)-1, np.exp(d/10)-1)))

val_preds_cycles  = model.predict(X_val).flatten()  * RUL_CLIP
test_preds_cycles = model.predict(X_test).flatten() * RUL_CLIP
test_preds_cycles = np.clip(test_preds_cycles, 0, RUL_CLIP)

y_val_cycles = y_val_raw  # unclipped, in cycles — val engines are from training data so max=125

rmse_val  = np.sqrt(mean_squared_error(y_val_cycles,  val_preds_cycles))
rmse_test = np.sqrt(mean_squared_error(y_test_clipped, test_preds_cycles))

print(f"\nVal RMSE:   {rmse_val:.2f}")
print(f"Test RMSE:  {rmse_test:.2f}")
print(f"NASA Score: {nasa_score(y_test_clipped, test_preds_cycles):.1f}")
print(f"Pred range: {test_preds_cycles.min():.1f} – {test_preds_cycles.max():.1f}")
print(f"True range: {y_test_clipped.min():.1f} – {y_test_clipped.max():.1f}")
# Out:
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# Val RMSE:   17.46
# Test RMSE:  27.95
# NASA Score: 42595.8
# Pred range: 5.0 – 122.0
# True range: 6.0 – 125.0

# %%
results = pd.DataFrame({
    'true_RUL': y_test_clipped,
    'pred_RUL': test_preds_cycles,
    'error':    test_preds_cycles - y_test_clipped,
    'abs_error': np.abs(test_preds_cycles - y_test_clipped)
})

# %%
print("\n=== Error by RUL bucket ===")
bins = [0, 30, 60, 90, 125]
labels = ['critical(0-30)', 'degrading(30-60)', 'mid(60-90)', 'healthy(90-125)']
results['bucket'] = pd.cut(results['true_RUL'], bins=bins, labels=labels)
print(results.groupby('bucket', observed=True)['abs_error'].agg(['mean','count']).round(2))
# Out:
# === Error by RUL bucket ===
#                        mean  count
# bucket
# critical(0-30)     4.690000     53
# degrading(30-60)  12.530000     38
# mid(60-90)        14.430000     40
# healthy(90-125)   23.969999    117

# %%
results['critical_true'] = results['true_RUL'] < 30
results['critical_pred'] = results['pred_RUL'] < 30
print("\n=== Critical zone (RUL < 30) ===")
print(confusion_matrix(results['critical_true'], results['critical_pred']))
print(classification_report(results['critical_true'], results['critical_pred'],
                             target_names=['safe', 'critical']))
# Out:
# === Critical zone (RUL < 30) ===
# [[186  10]
#  [  3  49]]
#               precision    recall  f1-score   support
#
#         safe       0.98      0.95      0.97       196
#     critical       0.83      0.94      0.88        52
#
#     accuracy                           0.95       248
#    macro avg       0.91      0.95      0.92       248
# weighted avg       0.95      0.95      0.95       248
